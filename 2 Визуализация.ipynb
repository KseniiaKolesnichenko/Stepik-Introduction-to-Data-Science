# %%
import pandas as pd
import numpy as np
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance=pd.read_csv('Data\StudentsPerformance.csv')
income=pd.read_csv('Data\income.csv')

dataset_209770_6=pd.read_csv('Data\dataset_209770_6.txt', sep=' ')
genome_matrix=pd.read_csv('Data\genome_matrix.csv', index_col=0)
dota_hero_stats=pd.read_csv('Data\dota_hero_stats.csv' )
iris=pd.read_csv('Data\iris.csv', index_col=0)


#students_performance1=pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPewriting scorerformance.csv')
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance = students_performance\
                                    .rename(columns=
                                            {'parental level of education': 'parental_level_of_education',
                                            'test preparation course': 'test_preparation_course',
                                            'math score': 'math_score',
                                            'reading score': 'reading_score',
                                            'writing score': 'writing_score'})

# %%
students_performance.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
students_performance.plot.scatter(x= 'math_score', y = 'reading_score')
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
sns.lmplot(x= 'math_score', y = 'reading_score', data = students_performance)

# %%
sns.lmplot(x= 'math_score', y = 'reading_score', data = students_performance, hue='gender', fit_reg=False)
#hue- группирующая переменная

# %%
ax=sns.lmplot(x= 'math_score', y = 'reading_score', data = students_performance, hue='gender', fit_reg=False)
#ax= название переменной
ax.set_xlabels('Math score')
ax.set_ylabels('Readindg score')

# %%
df=income
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df['income'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df.index, df.income)

# %%
df.income.plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
dataset_209770_6.head()
# Out:
#              x           y
# 0   104.944980  407.109173
# 1    95.961110  384.053031
# 2  1100.195804  487.124862
# 3  1094.499380  494.463625
# 4  1107.150760  500.539170

# %%
dataset_209770_6.columns
# Out:
# Index(['x', 'y'], dtype='object')

# %%
dataset_209770_6.plot.scatter(x= 'x', y = 'y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.scatterplot(dataset_209770_6.iloc[:, 0], dataset_209770_6.iloc[:, 1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
genome_matrix
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
#g = # ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
ax = sns.heatmap(genome_matrix, cmap="viridis",)

ax.xaxis.set_ticks_position('top')
ax.xaxis.set_tick_params(rotation=90)

# %%
dota_hero_stats
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dota_hero_stats.roles.value_counts()
# Out:
# ['Support', 'Nuker', 'Disabler', 'Escape']                           3
# ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker']               3
# ['Carry', 'Escape']                                                  3
# ['Support', 'Nuker', 'Disabler']                                     3
# ['Support', 'Disabler', 'Nuker']                                     3
#                                                                     ..
# ['Carry', 'Pusher', 'Nuker']                                         1
# ['Carry', 'Support', 'Durable', 'Disabler', 'Initiator', 'Nuker']    1
# ['Carry', 'Nuker', 'Disabler', 'Durable', 'Escape', 'Initiator']     1
# ['Nuker', 'Disabler']                                                1
# ['Support', 'Jungler', 'Pusher', 'Durable', 'Disabler']              1
# Name: roles, Length: 100, dtype: int64

# %%
df=pd.DataFrame(dota_hero_stats.roles)
dota_hero_stats['roles'].mode()
# Out:
# 0    ['Carry', 'Disabler', 'Initiator', 'Durable', ...
# 1                                  ['Carry', 'Escape']
# 2                     ['Support', 'Disabler', 'Nuker']
# 3           ['Support', 'Nuker', 'Disabler', 'Escape']
# 4                     ['Support', 'Nuker', 'Disabler']
# dtype: object

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
iris_parameters=iris[['sepal length','sepal width','petal length','petal width']]
iris_parameters
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
for column in iris_parameters:
    sns.kdeplot(data=iris_parameters)

# %%
sns.kdeplot(data=iris_parameters)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
petal_length=iris_parameters[['petal length']].sort_values
type(petal_length)
# Out:
# method

# %%
petal_length=iris_parameters[['petal length']]
petal_length
# Out:
#      petal length
# 0             1.4
# 1             1.4
# 2             1.3
# 3             1.5
# 4             1.4
# ..            ...
# 145           5.2
# 146           5.0
# 147           5.2
# 148           5.4
# 149           5.1
#
# [150 rows x 1 columns]

# %%
ax = sns.violinplot(y=petal_length.index, x="petal length", data=petal_length)
                    #,order=["Dinner", "Lunch"])

# %%
ax = sns.violinplot(x=petal_length["petal length"])

# %%
sns.pairplot(iris_parameters)
